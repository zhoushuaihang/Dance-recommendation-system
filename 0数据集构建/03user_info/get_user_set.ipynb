# %%
import  pandas as pd

# %%
dance_info=pd.read_csv('dance-info（0801-1231）.csv',encoding='utf-8')

# %%
len(dance_info)
# Out:
# 40866

# %%
dance_info.head(3)
# Out:
#           id                                           title  \
# 0  207000097                              亚洲舞王的乞丐舞，帅气，好多妹子围观
# 1  207000984  绝美！朱姐佳俊yyds！「舞剧 朱鹮」2021.07.31 晚场 返场‖卡司：朱洁静 王佳俊
# 2  207001016                                  弗拉明戈裙子优雅西班牙舞教学
#
#                               tag                 description      author  \
# 0     舞蹈暑期冲刺计划（8月）,跳舞,舞蹈,搞笑,原创,美女                           -       表哥爱跳舞
# 1              打卡挑战,舞剧,王佳俊,朱洁静,舞蹈  美琪大剧院 2楼 10排3座\n太美啦！给人以震撼！  joy4orever
# 2  校园UP主创作营,打卡挑战,舞蹈,舞蹈教学,弗拉门戈,西班牙                           -      7岁的小丫头
#
#    favorites  play              pubdate          bvid  \
# 0         27  3914  2021-08-04 22:15:36  BV12h411z7Zz
# 1          3    59  2021-08-01 12:18:27  BV12h411z7ax
# 2          1   156  2021-08-01 18:08:07  BV12h411z7af
#
#                                                  pic  \
# 0  //i0.hdslb.com/bfs/archive/7ed47af4502c6d18736...
# 1  //i0.hdslb.com/bfs/archive/dc50a14788917a31cce...
# ...

# %% [markdown]
# dance_info.head(3)

# %%
action_info=pd.read_csv('action_info(0801-1231).csv',encoding='utf-8')

# %%
len(action_info)
# Out:
# 376175

# %%
action_info.head()
# Out:
#     dance_id      user_id  lable
# 0  207000097  172874760.0      1
# 1  207000097   24696418.0      1
# 2  207000097  253183664.0      1
# 3  207000097  310786283.0      1
# 4  207000097   32507861.0      1

# %%
action_set=set()

# %%
for i in  range(len(action_info)):
    
    user=action_info['user_id'][i]
#     print(dance)
    action_set.add(user)

# %%
len(action_set)
# Out:
# 235673

# %%
user_info=pd.read_csv('user_info(0801-1031).csv',encoding='utf-8')

# %%
user_info.head()
# Out:
#            id birthday  level     name sex                               sign
# 0   100004596      NaN      4    无救小可爱  保密  积极者相信只有推动自己才能推动世界，只要推动自己就能推动世界。\n
# 1  1000081881      NaN      2  说好话给我听过  保密                                NaN
# 2    10000836    03-12      6     旺行天下   男              \'这个人很懒什么都没有留下(•͈˽•͈)
# 3   100010160    08-19      6  zhou-hj   男                   emmm\nemm\nem\ne
# 4   100011183      NaN      3     hl11  保密                                NaN

# %%
len(user_info)
# Out:
# 133216

# %%
user_info_set=set()
for i in  range(len(user_info)):
    user=user_info['id'][i]
#     print(dance)
    user_info_set.add(user)

# %%
len(user_info_set)
# Out:
# 133216

# %%
len(action_set-user_info_set)
# Out:
# 102458

# %%
235673-133216
# Out:
# 102457

# %%
user_set=action_set-user_info_set

# %%
len(user_set)
# Out:
# 102458

# %%
user_set
# Out:
# {39845891.0,
#  97517573.0,
#  358612998.0,
#  90963977.0,
#  498073615.0,
#  270008335.0,
#  217841680.0,
#  6291477.0,
#  488898581.0,
#  328990745.0,
#  501481501.0,
#  484704286.0,
#  406061087.0,
#  35.0,
#  412090406.0,
#  10747946.0,
#  11796527.0,
#  169345073.0,
#  174850099.0,
#  35127360.0,
#  315097154.0,
#  30670915.0,
#  86245443.0,
#  400293958.0,
#  648282182.0,
#  647233607.0,
#  413139044.0,
#  186384484.0,
#  435683430.0,
#  34078823.0,
#  405536872.0,
#  28311657.0,
#  201064553.0,
#  14418025.0,
#  38273133.0,
#  662175858.0,
#  406323320.0,
#  430440569.0,
#  361758842.0,
#  147587197.0,
#  129.0,
#  140247177.0,
#  36438157.0,
#  25690255.0,
#  1477443730.0,
#  492830874.0,
#  11010207.0,
#  151519394.0,
#  28836003.0,
#  698613922.0,
#  417595557.0,
#  1030488231.0,
#  39321768.0,
#  407634092.0,
#  220725421.0,
#  524462.0,
#  123207862.0,
#  96993467.0,
#  273416385.0,
#  1900544195.0,
#  89915589.0,
#  3670216.0,
#  667680968.0,
#  99352778.0,
# ...

# %%
user_li=list(user_set)
user_li
# Out:
# [39845891.0,
#  97517573.0,
#  358612998.0,
#  90963977.0,
#  498073615.0,
#  270008335.0,
#  217841680.0,
#  6291477.0,
#  488898581.0,
#  328990745.0,
#  501481501.0,
#  484704286.0,
#  406061087.0,
#  35.0,
#  412090406.0,
#  10747946.0,
#  11796527.0,
#  169345073.0,
#  174850099.0,
#  35127360.0,
#  315097154.0,
#  30670915.0,
#  86245443.0,
#  400293958.0,
#  648282182.0,
#  647233607.0,
#  413139044.0,
#  186384484.0,
#  435683430.0,
#  34078823.0,
#  405536872.0,
#  28311657.0,
#  201064553.0,
#  14418025.0,
#  38273133.0,
#  662175858.0,
#  406323320.0,
#  430440569.0,
#  361758842.0,
#  147587197.0,
#  129.0,
#  140247177.0,
#  36438157.0,
#  25690255.0,
#  1477443730.0,
#  492830874.0,
#  11010207.0,
#  151519394.0,
#  28836003.0,
#  698613922.0,
#  417595557.0,
#  1030488231.0,
#  39321768.0,
#  407634092.0,
#  220725421.0,
#  524462.0,
#  123207862.0,
#  96993467.0,
#  273416385.0,
#  1900544195.0,
#  89915589.0,
#  3670216.0,
#  667680968.0,
#  99352778.0,
# ...

# %%
name=['user_id']
test=pd.DataFrame(columns=name,data=user_set)
test.to_csv('user_set.csv',encoding='utf-8')

# %%
len(test)
# Out:
# 102458
